# %% [markdown]
# <a href="https://colab.research.google.com/github/marwamohamed51/Python_colab/blob/main/python_task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Task 1: Utility Functions:
1.Create the following functions:
    add_ numbers(a, b)
    subtract_ numbers(a, b)
    multiply_ numbers(a, b)
    divide_ numbers(a, b) Handle division by zero properly
"""

# %%
"""
Task 2: Discount Calculator:
1.Create a function:
    apply_discount(price, discount_rate)
    Inside the function:
    Use a lambda function to calculate the final price
    ask for a price from end user and Return the discounted price
"""

# %%
"""
Task 3: Console Calculator:
Build a calculator that:
Uses functions only
Supports:
    Addition
    Subtraction
    Multiplication
    Division
    Runs in a loop until the user chooses to exit
    Must Include:
    Input validation
    Clear menu
    Reusable functions
"""

# %%
#Task 4: Hacker Rank

# %%
#1. Write a Function
def is_leap(year):
   # leap = False

    # Write your logic here
    if(year % 4 == 0):
        if(year % 100 == 0):
            if(year % 400 == 0):
                return True
            else:
                return False
        else:
            return True
    else:
        return False


    return leap

year = int(input())
print(is_leap(year))
# Out:
# 4444
# True

# %%
##2. Python Lists
list = []
list.insert(0,5)
list.insert(1,10)
list.insert(0,6)
print(list)

list.remove(6)
list.append(9)
list.append(1)
list.sort()
print(list)


list.pop()
list.reverse()
print(list)
# Out:
# [6, 5, 10]
# [1, 5, 9, 10]
# [9, 5, 1]

# %%
#3. Tuples
n = int(input())
integer_list = tuple(map(int, input().split()))
print (hash(integer_list))
# Out:
# 2
# 12
# -860454829093830431

# %%
#4. Dictionaries

# %%
#5. Nested Lists

# %%
#6. Simple Array Sum

# %%
#7. Mini-Max Sum
